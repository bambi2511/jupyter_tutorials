# %%
import numpy as np
import pandas as pd
from IPython.display import YouTubeVideo
import os
from urllib.request import urlretrieve
import matplotlib.pyplot as plt
import jvdp_workflow
plt.style.use('seaborn')
# %matplotlib inline

# %%
M = 0
for i in range(10000):
    trials = np.random.randint(2, size=30)
    if (trials.sum() >= 22):
        M += 1
p = M / 10000
p
# Out:
# 0.0086

# %%
def embed_video(index, playlist='PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ'):
    return YouTubeVideo('', index=index - 1, list=playlist, width=800, height=600)

# %%
embed_video(1)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=0&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
URL = 'https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD'

# %%
#def get_fremont_data(filename='Fremont.csv', url = URL, force_download=False):
#    if force_download or not os.path.exists(filename):
#        urlretrieve(url, filename)
#    data = pd.read_csv(filename, index_col='Date', parse_dates=True)
#    data.columns = ['West', 'East']
#    data['Total'] = data.West + data.East
#    return data

# %%
from jvdp_workflow.data import get_fremont_data

# %%
data = get_fremont_data()

# %%
data.resample('W').sum().plot()

# %%
embed_video(2)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=1&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
ax = data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0, None)
# Out:
# (0, 1059460.05)

# %%
data.groupby(data.index.time).mean().plot()

# %%
pivoted = data.pivot_table("Total", index=data.index.time, columns=data.index.date)
pivoted.iloc[:5, :5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend=False, alpha=0.01)

# %%
data_we = data.iloc[data.index.dayofweek.isin(['5', '6']),:].dropna()
pivoted_we = data_we.pivot_table("Total", index=data_we.index.time, columns=data_we.index.date)
pivoted_we.iloc[:5, :5]
# Out:
#           2012-10-06  2012-10-07  2012-10-13  2012-10-14  2012-10-20
# 00:00:00        15.0        11.0        18.0         6.0         9.0
# 01:00:00        15.0        17.0        11.0         9.0         8.0
# 02:00:00         9.0         3.0        16.0         8.0        12.0
# 03:00:00         3.0         6.0         4.0         4.0         5.0
# 04:00:00         5.0         3.0         3.0         5.0         3.0

# %%
pivoted_we.plot(legend=False, alpha=0.01)

# %%
embed_video(3)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=2&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
embed_video(4)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=3&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
embed_video(5)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=4&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
get_fremont_data??

# %%
help(get_fremont_data)
#shift tab
# Out:
# Help on function get_fremont_data in module jvdp_workflow.data:
#
# get_fremont_data(filename='Fremont.csv', url='https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD', force_download=False)
#     Download and cache the Fremont data
#
#     Parameters
#     ----------
#     filename : string (optional)
#                location to save the data
#     url : string (optional)
#           web location of the data
#     force_download : bool (optional)
#                      If True then force data download
#     Returns
#     -------
#     data: pandas Dataframe
#           the Fremont bridge data

# %%
embed_video(6)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=5&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
embed_video(7)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=6&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
embed_video(8)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?index=7&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
