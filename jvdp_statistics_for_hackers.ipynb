# %%
import numpy as np
import pandas as pd

# %%
M = 0
for i in range(10000):
    trials = np.random.randint(2, size=30)
    if (trials.sum() >= 22):
        M += 1
p = M / 10000
p
# Out:
# 0.0073

# %%
from IPython.display import YouTubeVideo
def embed_video(index, playlist='PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ'):
    return YouTubeVideo('', index=index - 1, list=playlist, width=800, height=600)

# %%
embed_video(1)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ&index=0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
URL = 'https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD'

# %%
from urllib.request import urlretrieve
urlretrieve(URL, 'Fremont.csv')
# Out:
# ('Fremont.csv', <http.client.HTTPMessage at 0x7f771ac30a20>)

# %%
# !head Fremont.csv
# Out:
# Date,Fremont Bridge West Sidewalk,Fremont Bridge East Sidewalk
# 10/03/2012 12:00:00 AM,4,9
# 10/03/2012 01:00:00 AM,4,6
# 10/03/2012 02:00:00 AM,1,1
# 10/03/2012 03:00:00 AM,2,3
# 10/03/2012 04:00:00 AM,6,1
# 10/03/2012 05:00:00 AM,21,10
# 10/03/2012 06:00:00 AM,105,50
# 10/03/2012 07:00:00 AM,257,95
# 10/03/2012 08:00:00 AM,291,146

# %%
data = pd.read_csv('Fremont.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
# %matplotlib inline
data.resample('W').sum().plot()

# %%
embed_video(2)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ&index=1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
data.columns = ('West', 'East')
data.resample('W').sum().plot()

# %%
data["Total"] = data.West + data.East

ax = data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0, None)
# Out:
# (0, 1059460.05)

# %%
data.groupby(data.index.time).mean().plot()

# %%
pivoted = data.pivot_table("Total", index=data.index.time, columns=data.index.date)
pivoted.iloc[:5, :5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend=False, alpha=0.01)

# %%
data_we = data.iloc[data.index.dayofweek.isin(['5', '6']),:].dropna()
pivoted_we = data_we.pivot_table("Total", index=data_we.index.time, columns=data_we.index.date)
pivoted_we.iloc[:5, :5]
# Out:
#           2012-10-06  2012-10-07  2012-10-13  2012-10-14  2012-10-20
# 00:00:00        15.0        11.0        18.0         6.0         9.0
# 01:00:00        15.0        17.0        11.0         9.0         8.0
# 02:00:00         9.0         3.0        16.0         8.0        12.0
# 03:00:00         3.0         6.0         4.0         4.0         5.0
# 04:00:00         5.0         3.0         3.0         5.0         3.0

# %%
pivoted_we.plot(legend=False, alpha=0.01)

# %%
embed_video(3)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.youtube.com/embed/?list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ&index=2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Out:
# Int64Index([2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#             ...
#             3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#            dtype='int64', name='Date', length=45240)
